# %% [markdown]
# ### installing modules. remove when done

# %%
# !pip install trl
# !pip install peft
# !pip install torch
# !pip install datasets
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 139.1/139.1 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 8.2/8.2 MB 4.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 78.9/78.9 kB 630.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 507.1/507.1 kB 3.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 265.7/265.7 kB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 3.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 277.3/277.3 kB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 330.3/330.3 kB 3.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 240.6/240.6 kB 1.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 166.4/166.4 kB 1.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 134.8/134.8 kB 2.0 MB/s eta 0:00:00
# ...
